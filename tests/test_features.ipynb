# %%
import os
import sys
import numpy as np

def path_link(path:str):
    sys.path.append(path)

path_link('../code/lib')

import features as ft
import simulation as sim

# %% [markdown]
# ### Global variables

# %%
print(f'NB_HIST >>>>> {ft.NB_HIST}')
print(f'THRESHOLD_DIST >>>>> {ft.THRESHOLD_DIST}')
print(f'NUMBER_ROLLOUT >>>>> {ft.NUMBER_ROLLOUT}')
print(f'FEATURE_SHAPE >>>>> {ft.FEATURE_SHAPE}')
print(f'EDGE_SHAPE >>>>> {ft.EDGE_SHAPE}')
print(f'MIN_DIST >>>>> {ft.MIN_DIST}')
print(f'MAX_DIST >>>>> {ft.MAX_DIST}')
print(f'MIN_X >>>>> {ft.MIN_X}')
print(f'MAX_X >>>>> {ft.MAX_X}')
print(f'MIN_Y >>>>> {ft.MIN_Y}')
print(f'MAX_Y >>>>> {ft.MAX_Y}')
# Out:
# NB_HIST >>>>> 4
# THRESHOLD_DIST >>>>> 6
# NUMBER_ROLLOUT >>>>> 10
# FEATURE_SHAPE >>>>> 17
# EDGE_SHAPE >>>>> 3
# MIN_DIST >>>>> 0
# MAX_DIST >>>>> 6
# MIN_X >>>>> -120
# MAX_X >>>>> 120
# MIN_Y >>>>> -120
# MAX_Y >>>>> 120

# %% [markdown]
# ### =======

# %% [markdown]
# ### Force expression

# %% [markdown]
# ### Testing the features

# %%
# generate a simulation
data = sim.compute_main(100, (70, 5.5, 3.4, 0.4), 120)[0]

# get speeds
v = ft.getSpeeds(data)

mat = ft.getFeatures(data, np.array([0.1]))

featuresData = mat[0]

nextState = mat[1]
# Out:
# v0:70, tau:5.5, k:3.4, epsilon:0.4
# 100%|██████████| 100/100 [00:01<00:00, 86.11it/s]

# %%
print(data[:,0,:])
# Out:
# [[ -8.15599412  -5.92841253]
#  [ -7.8821651   -6.53049684]
#  [ -7.62863066  -7.12378241]
#  [ -7.35213207  -7.68481874]
#  [ -6.97965432  -8.30145637]
#  [ -6.67204638  -8.87935115]
#  [ -6.36155527  -9.47305893]
#  [ -6.12805555 -10.04636603]
#  [ -5.79903269 -10.64766281]
#  [ -5.47457307 -11.22717966]
#  [ -5.14763267 -11.83332985]
#  [ -4.83080935 -12.40862511]
#  [ -4.51845629 -12.98583992]
#  [ -4.1901708  -13.59646429]
#  [ -3.88837984 -14.20882505]
#  [ -3.61165207 -14.87740479]
#  [ -3.27918525 -15.55265563]
#  [ -2.95227141 -16.18078598]
#  [ -2.65172114 -16.79301921]
#  [ -2.30851585 -17.42703372]
#  [ -1.98890257 -18.04980763]
#  [ -1.66928928 -18.67258154]
#  [ -1.349676   -19.29535546]
#  [ -1.03006272 -19.91812937]
#  [ -0.71044943 -20.54090329]
#  [ -0.39083615 -21.1636772 ]
#  [ -0.07122287 -21.78645112]
#  [  0.24839042 -22.40922503]
#  [  0.5680037  -23.03199895]
#  [  0.88761698 -23.65477286]
#  [  1.20723027 -24.27754678]
#  [  1.52684355 -24.90032069]
#  [  1.84645683 -25.52309461]
#  [  2.16607012 -26.14586852]
#  [  2.4856834  -26.76864244]
#  [  2.80529669 -27.39141635]
#  [  3.12490997 -28.01419027]
#  [  3.44452325 -28.63696418]
#  [  3.76413654 -29.2597381 ]
#  [  4.08374982 -29.88251201]
#  [  4.4033631  -30.50528593]
#  [  4.72297639 -31.12805984]
#  [  5.04258967 -31.75083376]
#  [  5.36220295 -32.37360767]
#  [  5.68181624 -32.99638159]
#  [  6.00142952 -33.6191555 ]
#  [  6.3210428  -34.24192942]
#  [  6.64065609 -34.86470333]
#  [  6.96026937 -35.48747725]
#  [  7.27988265 -36.11025116]
#  [  7.59949594 -36.73302508]
#  [  7.91910922 -37.35579899]
#  [  8.2387225  -37.97857291]
#  [  8.55833579 -38.60134682]
#  [  8.87794907 -39.22412074]
#  [  9.19756235 -39.84689465]
#  [  9.51717564 -40.46966857]
#  [  9.83678892 -41.09244248]
#  [ 10.1564022  -41.7152164 ]
#  [ 10.47601549 -42.33799031]
#  [ 10.79562877 -42.96076423]
#  [ 11.11524205 -43.58353814]
#  [ 11.43485534 -44.20631205]
#  [ 11.75446862 -44.82908597]
#  [ 12.0740819  -45.45185988]
#  [ 12.39369519 -46.0746338 ]
#  [ 12.71330847 -46.69740771]
#  [ 13.03292175 -47.32018163]
#  [ 13.35253504 -47.94295554]
#  [ 13.67214832 -48.56572946]
#  [ 13.99176161 -49.18850337]
#  [ 14.31137489 -49.81127729]
#  [ 14.63098817 -50.4340512 ]
#  [ 14.95060146 -51.05682512]
#  [ 15.27021474 -51.67959903]
#  [ 15.58982802 -52.30237295]
#  [ 15.90944131 -52.92514686]
#  [ 16.22905459 -53.54792078]
#  [ 16.54866787 -54.17069469]
#  [ 16.86828116 -54.79346861]
#  [ 17.18789444 -55.41624252]
#  [ 17.50750772 -56.03901644]
#  [ 17.82712101 -56.66179035]
#  [ 18.14673429 -57.28456427]
#  [ 18.46634757 -57.90733818]
#  [ 18.78596086 -58.5301121 ]
#  [ 19.10557414 -59.15288601]
#  [ 19.42518742 -59.77565993]
#  [ 19.74480071 -60.39843384]
#  [ 20.06441399 -61.02120776]
#  [ 20.38402727 -61.64398167]
#  [ 20.70364056 -62.26675559]
#  [ 21.02325384 -62.8895295 ]
#  [ 21.34286712 -63.51230342]
#  [ 21.66248041 -64.13507733]
#  [ 21.98209369 -64.75785125]
#  [ 22.30170697 -65.38062516]
#  [ 22.61606058 -66.03005596]
#  [ 22.9319624  -66.67752541]
#  [ 23.24924775 -67.32314351]]

# %%
for i in range(10):
    print(featuresData[i][0])
# Out:
# tensor([ 0.2738, -0.6021,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.1000])
# tensor([ 0.2535, -0.5933,  0.2738, -0.6021,  0.0000,  0.0000,  0.0000,  0.0000,
#          0.1000])
# tensor([ 0.2765, -0.5610,  0.2535, -0.5933,  0.2738, -0.6021,  0.0000,  0.0000,
#          0.1000])
# tensor([ 0.3725, -0.6166,  0.2765, -0.5610,  0.2535, -0.5933,  0.2738, -0.6021,
#          0.1000])
# tensor([ 0.3076, -0.5779,  0.3725, -0.6166,  0.2765, -0.5610,  0.2535, -0.5933,
#          0.1000])
# tensor([ 0.3105, -0.5937,  0.3076, -0.5779,  0.3725, -0.6166,  0.2765, -0.5610,
#          0.1000])
# tensor([ 0.2335, -0.5733,  0.3105, -0.5937,  0.3076, -0.5779,  0.3725, -0.6166,
#          0.1000])
# tensor([ 0.3290, -0.6013,  0.2335, -0.5733,  0.3105, -0.5937,  0.3076, -0.5779,
#          0.1000])
# tensor([ 0.3245, -0.5795,  0.3290, -0.6013,  0.2335, -0.5733,  0.3105, -0.5937,
#          0.1000])
# tensor([ 0.3269, -0.6062,  0.3245, -0.5795,  0.3290, -0.6013,  0.2335, -0.5733,
#          0.1000])

# %% [markdown]
# ### =======

# %% [markdown]
# ### Edges

# %%
edge_ind, edge_atr = ft.getEdges(data)

# %%
print(edge_atr[50])
# Out:
# tensor([[ 0.5814, -3.4112,  0.7299],
#         [ 0.5802, -3.0714,  1.6382],
#         [ 0.8022, -4.4251,  1.8942],
#         [ 0.4674,  1.3533,  2.4564],
#         [ 0.2059, -1.0834,  0.5938],
#         [ 0.4405,  2.1890, -1.4814],
#         [ 0.2472,  0.8353, -1.2255],
#         [ 0.7749, -1.5385, -4.3874],
#         [ 0.5141, -2.4800,  1.8340],
#         [ 0.2985, -0.1129, -1.7876],
#         [ 0.4564,  2.6836,  0.5460],
#         [ 0.6521,  2.7107,  2.8217],
#         [ 0.7359, -0.7982,  4.3425],
#         [ 0.7057, -1.7614, -3.8503],
#         [ 0.4752, -2.7443, -0.7725],
#         [ 0.3347, -0.1311,  2.0037],
#         [ 0.8301,  4.7441,  1.5174],
#         [ 0.3477,  1.2644, -1.6596],
#         [ 0.8692, -4.0264, -3.3143],
#         [ 0.7412, -2.2200, -3.8535],
#         [ 0.6354,  2.6132,  2.7761],
#         [ 0.6718, -2.4779, -3.1791],
#         [ 0.2951, -0.3747,  1.7308],
#         [ 0.2679, -0.1831,  1.5972],
#         [ 0.3752, -1.9866,  1.0595],
#         [ 0.6021, -3.4020, -1.2152],
#         [ 0.8264, -3.5479,  3.4641],
#         [ 0.3626,  1.8766, -1.1009],
#         [ 0.8688, -5.1487,  0.8137],
#         [ 0.9969, -5.1216,  3.0894],
#         [ 0.2616,  1.1564, -1.0610],
#         [ 0.6367,  0.8501,  3.7246],
#         [ 0.7853, -3.4797, -3.1769],
#         [ 0.9954, -3.2522,  5.0092],
#         [ 0.2833, -0.3034, -1.6723],
#         [ 0.9104,  3.3366,  4.3251],
#         [ 0.6002,  3.5647,  0.5116],
#         [ 0.7403,  3.8681,  2.1839],
#         [ 0.8095,  4.4878,  1.8568],
#         [ 0.4380, -2.2959,  1.2791],
#         [ 0.5080,  1.9006,  2.3832],
#         [ 0.5732,  1.0508,  3.2745],
#         [ 0.5281, -2.0101,  2.4497],
#         [ 0.9128, -4.5974,  2.9762],
#         [ 0.0389,  0.1916, -0.1336],
#         [ 0.2910, -1.6119, -0.6713],
#         [ 0.5112, -2.4367, -1.8626],
#         [ 0.6709,  0.8357, -3.9378],
#         [ 0.6197, -0.5180, -3.6818],
#         [ 0.3881,  0.2827, -2.3115],
#         [ 0.8762,  4.1136,  3.2731],
#         [ 0.9067,  0.1091, -5.4393],
#         [ 0.7992, -0.3063,  4.7855],
#         [ 0.5393,  2.9914, -1.2338],
#         [ 0.4935, -0.3215, -2.9432],
#         [ 0.7810, -1.0166,  4.5741],
#         [ 0.5148,  3.0573, -0.4389],
#         [ 0.5283, -3.0609, -0.8247],
#         [ 0.9427, -5.6481, -0.2983],
#         [ 0.8423,  4.8056, -1.5641],
#         [ 0.6213, -3.3129, -1.7094],
#         [ 0.9051, -5.3896,  0.6678],
#         [ 0.4400, -2.5872,  0.5264],
#         [ 0.3793,  0.0271,  2.2757],
#         [ 0.9008, -0.3887, -5.3908],
#         [ 0.7232,  4.1965,  1.1042],
#         [ 0.9759, -3.9715,  4.3030],
#         [ 0.6367,  0.2281, -3.8135],
#         [ 0.6289,  2.8660, -2.4544],
#         [ 0.9239, -5.2908, -1.6548],
#         [ 0.3693, -2.1652, -0.4716],
#         [ 0.3469,  2.0763, -0.1456],
#         [ 0.6458,  3.2724, -2.0752],
#         [ 0.4407,  1.9186, -1.8192],
#         [ 0.7211,  2.3670, -3.6217],
#         [ 0.6492,  3.3967,  1.9061],
#         [ 0.5577,  3.1701,  1.0702],
#         [ 0.1443, -0.2265, -0.8358],
#         [ 0.2296, -1.3537,  0.2560],
#         [ 0.5299,  1.6306, -2.7293],
#         [ 0.3137, -1.8035, -0.5377],
#         [ 0.9005, -5.3876,  0.4073],
#         [ 0.5814,  0.7299, -3.4112],
#         [ 0.5802,  1.6382, -3.0714],
#         [ 0.8022,  1.8942, -4.4251],
#         [ 0.4674,  2.4564,  1.3533],
#         [ 0.2059,  0.5938, -1.0834],
#         [ 0.4405, -1.4814,  2.1890],
#         [ 0.2472, -1.2255,  0.8353],
#         [ 0.7749, -4.3874, -1.5385],
#         [ 0.5141,  1.8340, -2.4800],
#         [ 0.2985, -1.7876, -0.1129],
#         [ 0.4564,  0.5460,  2.6836],
#         [ 0.6521,  2.8217,  2.7107],
#         [ 0.7359,  4.3425, -0.7982],
#         [ 0.7057, -3.8503, -1.7614],
#         [ 0.4752, -0.7725, -2.7443],
#         [ 0.3347,  2.0037, -0.1311],
#         [ 0.8301,  1.5174,  4.7441],
#         [ 0.3477, -1.6596,  1.2644],
#         [ 0.8692, -3.3143, -4.0264],
#         [ 0.7412, -3.8535, -2.2200],
#         [ 0.6354,  2.7761,  2.6132],
#         [ 0.6718, -3.1791, -2.4779],
#         [ 0.2951,  1.7308, -0.3747],
#         [ 0.2679,  1.5972, -0.1831],
#         [ 0.3752,  1.0595, -1.9866],
#         [ 0.6021, -1.2152, -3.4020],
#         [ 0.8264,  3.4641, -3.5479],
#         [ 0.3626, -1.1009,  1.8766],
#         [ 0.8688,  0.8137, -5.1487],
#         [ 0.9969,  3.0894, -5.1216],
#         [ 0.2616, -1.0610,  1.1564],
#         [ 0.6367,  3.7246,  0.8501],
#         [ 0.7853, -3.1769, -3.4797],
#         [ 0.9954,  5.0092, -3.2522],
#         [ 0.2833, -1.6723, -0.3034],
#         [ 0.9104,  4.3251,  3.3366],
#         [ 0.6002,  0.5116,  3.5647],
#         [ 0.7403,  2.1839,  3.8681],
#         [ 0.8095,  1.8568,  4.4878],
#         [ 0.4380,  1.2791, -2.2959],
#         [ 0.5080,  2.3832,  1.9006],
#         [ 0.5732,  3.2745,  1.0508],
#         [ 0.5281,  2.4497, -2.0101],
#         [ 0.9128,  2.9762, -4.5974],
#         [ 0.0389, -0.1336,  0.1916],
#         [ 0.2910, -0.6713, -1.6119],
#         [ 0.5112, -1.8626, -2.4367],
#         [ 0.6709, -3.9378,  0.8357],
#         [ 0.6197, -3.6818, -0.5180],
#         [ 0.3881, -2.3115,  0.2827],
#         [ 0.8762,  3.2731,  4.1136],
#         [ 0.9067, -5.4393,  0.1091],
#         [ 0.7992,  4.7855, -0.3063],
#         [ 0.5393, -1.2338,  2.9914],
#         [ 0.4935, -2.9432, -0.3215],
#         [ 0.7810,  4.5741, -1.0166],
#         [ 0.5148, -0.4389,  3.0573],
#         [ 0.5283, -0.8247, -3.0609],
#         [ 0.9427, -0.2983, -5.6481],
#         [ 0.8423, -1.5641,  4.8056],
#         [ 0.6213, -1.7094, -3.3129],
#         [ 0.9051,  0.6678, -5.3896],
#         [ 0.4400,  0.5264, -2.5872],
#         [ 0.3793,  2.2757,  0.0271],
#         [ 0.9008, -5.3908, -0.3887],
#         [ 0.7232,  1.1042,  4.1965],
#         [ 0.9759,  4.3030, -3.9715],
#         [ 0.6367, -3.8135,  0.2281],
#         [ 0.6289, -2.4544,  2.8660],
#         [ 0.9239, -1.6548, -5.2908],
#         [ 0.3693, -0.4716, -2.1652],
#         [ 0.3469, -0.1456,  2.0763],
#         [ 0.6458, -2.0752,  3.2724],
#         [ 0.4407, -1.8192,  1.9186],
#         [ 0.7211, -3.6217,  2.3670],
#         [ 0.6492,  1.9061,  3.3967],
#         [ 0.5577,  1.0702,  3.1701],
#         [ 0.1443, -0.8358, -0.2265],
#         [ 0.2296,  0.2560, -1.3537],
#         [ 0.5299, -2.7293,  1.6306],
#         [ 0.3137, -0.5377, -1.8035],
#         [ 0.9005,  0.4073, -5.3876]])

# %%
d = {}

for i in range(len(edge_ind[80][0])):
    if edge_ind[80][0, i].item() not in d:
        d[edge_ind[80][0, i].item()] = {}
    d[edge_ind[80][0, i].item()][edge_ind[80][1, i].item()] = edge_atr[80][i]
    #print(f'{edge_ind[80][0, i].item()} ---- {edge_ind[80][1, i].item()}')

# %%
print(d[1])
print(d[17])
print(d[92])
# Out:
# {17: tensor([ 0.5721, -0.4936,  3.3969]), 92: tensor([ 0.9019, -0.3360,  5.4007])}
# {92: tensor([0.3350, 0.1576, 2.0039]), 1: tensor([ 0.5721,  3.3969, -0.4936]), 4: tensor([ 0.5749, -3.3533,  0.8082])}
# {1: tensor([ 0.9019,  5.4007, -0.3360]), 4: tensor([ 0.2766, -1.3495,  0.9658]), 17: tensor([0.3350, 2.0039, 0.1576]), 33: tensor([ 0.8419, -4.8117, -1.5384])}
